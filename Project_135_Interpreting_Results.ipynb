# %%
from google.colab import files
files = files.upload()
# Out:
#      <input type="file" id="files-89eb5002-b14f-43a7-96fa-8e0af2591d8b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-89eb5002-b14f-43a7-96fa-8e0af2591d8b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Stars.csv to Stars.csv

# %%
rows = []
import csv
import pandas as pd

with open("Stars.csv") as f:
  csvreader = csv.reader(f)
  for row in csvreader:
    rows.append(row)

headers = rows[0]
headers[0] = 'index' 
print(headers)
# Out:
# ['index', 'Star Name', 'Distance', 'Mass', 'Radius', 'Gravity']

# %%
import pandas as pd

df = pd.read_csv('Stars.csv')

star_name = df['Star Name'].tolist()
star_name.pop(0)

mass = df['Mass'].tolist()
mass.pop(0)

radius = df['Radius'].tolist()
radius.pop(0)

distance = df['Distance'].tolist()
distance.pop(0)

gravity = df['Gravity'].tolist()
gravity.pop(0)
# Out:
# 274.2691615

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (10,5))
plt.title('Stars Vs Mass')
plt.xlabel('Name')
plt.ylabel('Mass')
plt.bar(star_name[0:9], mass[0:9])
# Out:
# <BarContainer object of 9 artists>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (10,5))
plt.title('Stars Vs Radius')
plt.xlabel('Name')
plt.ylabel('Radius')
plt.bar(star_name[0:9], radius[0:9])
# Out:
# <BarContainer object of 9 artists>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (10,5))
plt.title('Stars Vs Distance')
plt.xlabel('Name')
plt.ylabel('Distance')
plt.bar(star_name[0:9], distance[0:9])
# Out:
# <BarContainer object of 9 artists>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (10,5))
plt.title('Stars Vs Gravity')
plt.xlabel('Name')
plt.ylabel('Gravity')
plt.bar(star_name[0:9], gravity[0:9])
# Out:
# <BarContainer object of 9 artists>

# %%
final_planet_list = []

for planet_data in rows:
  temp_dict = {
      'name' : planet_data[1],
      'distance' : planet_data[2],
      'planet_mass' : planet_data[3],
      'planet_radius' : planet_data[4],
      'gravity' : planet_data[5],
  }
  final_planet_list.append(temp_dict)

print(final_planet_list)
# Out:
# [{'name': 'Star Name', 'distance': 'Distance', 'planet_mass': 'Mass', 'planet_radius': 'Radius', 'gravity': 'Gravity'}, {'name': 'Sun', 'distance': '0.000015813', 'planet_mass': '1', 'planet_radius': '1', 'gravity': '274.2691615'}, {'name': 'Sirius', 'distance': '8.6', 'planet_mass': '2.1', 'planet_radius': '1.71', 'gravity': '196.9717996'}, {'name': 'Canopus', 'distance': '310', 'planet_mass': '15', 'planet_radius': '71', 'gravity': '0.816115339'}, {'name': 'Alpha Centauri', 'distance': '4.4', 'planet_mass': '1.1', 'planet_radius': '1.2', 'gravity': '209.511165'}, {'name': 'Arcturus', 'distance': '37', 'planet_mass': '1.1', 'planet_radius': '26', 'gravity': '0.446295973'}, {'name': 'Vega', 'distance': '25', 'planet_mass': '2.2', 'planet_radius': '2.7', 'gravity': '82.76984296'}, {'name': 'Capella', 'distance': '43', 'planet_mass': '2.6', 'planet_radius': '12', 'gravity': '4.952082082'}, {'name': 'Rigel', 'distance': '860', 'planet_mass': '23', 'planet_radius': '78.9', 'gravity': '1.013329785'}, {'name': 'Procyon', 'distance': '11.4', 'planet_mass': '1.5', 'planet_radius': '1.9', 'gravity': '113.9622555'}, {'name': 'Betelgeuse', 'distance': '0640[1]', 'planet_mass': '20', 'planet_radius': '950', 'gravity': '0.006077987'}, {'name': 'Achernar', 'distance': '144', 'planet_mass': '6.7', 'planet_radius': '9.3', 'gravity': '21.24642597'}, {'name': 'Hadar', 'distance': '390', 'planet_mass': '10.5', 'planet_radius': '8.6', 'gravity': '38.93761757'}, {'name': 'Altair', 'distance': '17', 'planet_mass': '1.8', 'planet_radius': '1.8', 'gravity': '152.3717564'}, {'name': 'Acrux', 'distance': '320', 'planet_mass': '18', 'planet_radius': '8.9', 'gravity': '62.32603088'}, {'name': 'Aldebaran', 'distance': '65', 'planet_mass': '1.5', 'planet_radius': '44', 'gravity': '0.212501933'}, {'name': 'Antares', 'distance': '600', 'planet_mass': '12', 'planet_radius': '680', 'gravity': '0.007117712'}, {'name': 'Spica', 'distance': '260', 'planet_mass': '11.43', 'planet_radius': '7.47', 'gravity': '56.18003501'}, {'name': 'Pollux', 'distance': '34', 'planet_mass': '1.9', 'planet_radius': '8.8', 'gravity': '6.729227877'}, {'name': 'Fomalhaut', 'distance': '25', 'planet_mass': '1.9', 'planet_radius': '1.8', 'gravity': '160.8368539'}, {'name': 'Deneb', 'distance': '2,600', 'planet_mass': '19', 'planet_radius': '203', 'gravity': '0.126455727'}, {'name': 'Mimosa', 'distance': '350', 'planet_mass': '16', 'planet_radius': '8.4', 'gravity': '62.19255362'}, {'name': 'Regulus', 'distance': '77', 'planet_mass': '3.8', 'planet_radius': '3.1', 'gravity': '108.4519057'}, {'name': 'Adhara', 'distance': '430', 'planet_mass': '12.5', 'planet_radius': '14', 'gravity': '17.49165571'}, {'name': 'Shaula', 'distance': '700', 'planet_mass': '14.5', 'planet_radius': '8.8', 'gravity': '51.3546338'}, {'name': 'Castor', 'distance': '52', 'planet_mass': '2.8', 'planet_radius': '2.4', 'gravity': '133.3252868'}, {'name': 'Gacrux', 'distance': '88', 'planet_mass': '1.5', 'planet_radius': '84', 'gravity': '0.058305519'}, {'name': 'Bellatrix', 'distance': '240', 'planet_mass': '8.6', 'planet_radius': '5.8', 'gravity': '70.11637302'}, {'name': 'Elnath', 'distance': '130', 'planet_mass': '5', 'planet_radius': '4.2', 'gravity': '77.74069202'}, {'name': 'Miaplacidus', 'distance': '110', 'planet_mass': '3.5', 'planet_radius': '6.8', 'gravity': '20.75999276'}, {'name': 'Alnilam', 'distance': '2,000', 'planet_mass': '32', 'planet_radius': '42', 'gravity': '4.97540429'}, {'name': 'Gamma Velorum', 'distance': '1,100', 'planet_mass': '9', 'planet_radius': '6', 'gravity': '68.56729036'}, {'name': 'Alnair', 'distance': '101', 'planet_mass': '4', 'planet_radius': '3.4', 'gravity': '94.90282403'}, {'name': 'Alioth', 'distance': '81', 'planet_mass': '2.9', 'planet_radius': '4.2', 'gravity': '45.08960137'}, {'name': 'Alnitak', 'distance': '1050', 'planet_mass': '33', 'planet_radius': '20', 'gravity': '22.62720582'}, {'name': 'Dubhe', 'distance': '120', 'planet_mass': '4.25', 'planet_radius': '30', 'gra ...
